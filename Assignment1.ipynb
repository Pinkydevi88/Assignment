# %%
# 1. In the below elements which of them are values or an expression? Eg:- values can be integer or string and expressions will be mathematical operators.
* 
'hello'
-87.8
- 
/ 
+
6 

Ans: Values:
    'hello'
    -87.8
     6
    Mathematical expression:
     *
     -
     /
     +

#2. What is the difference between string and variable?
Ans:
Variable is where data is declared to a reserved memory location. Its an empty box to fill with any type of data whereas string is a data to fill that empty box. 
Eg. a ="ineuron", a is a variable and “ineuron” is a data.    

#3. Describe three different data types.
Ans:   int    ; It is an integer type where data is assigned as a numeric value. Eg. a=10,b=20.
       float  ; It is a decimal type where data is assigned as a decimal value. Eg. a=10.29,b=-45.89,.
       string ; It is a collection of one or more character which is declared inside "" or ''. Eg. a ="ineuron",
    b='education'

#4. What is an expression made up of? What do all expressions do?
Ans: An expression is made up of all combinations of values,operators, methods which is constructed to a syntax to get desired outcome in a single value. 
    Eg. This is an expression: >>> 3 + 2. Both values are integer values and the + is the mathematical operator.
        This expression evaluates down to the single integer value 5.
    
#5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
Ans: An assignment statement gives value to a variable and its just print it. In other side expression is a combine of 
    value, operator etc. 
    Here spam = 10 , there is no operator to work on like =,-,* etc so this is not an expression instead its a statement, 
    an assignment statement where the output will be "10".
    
#6. After running the following code, what does the variable bacon contain?
bacon = 22
bacon + 1
Ans: 23.

#7. What should the values of the following two terms be?
'spam' + 'spamspam'
'spam' * 3
Ans: 'spam' + 'spamspam' -'spamspamspam'
     'spam' * 3          -'spamspamspam'

#8. Why is eggs a valid variable name while 100 is invalid?
Ans: A variable name cannot start with a number. A variable name can only contain alpha-numeric characters and 
    underscores. "eggs" is alpha character whereas "100" is a number.
    
#9. What three functions can be used to get the integer, floating-point number, or string version of a value?
Ans: Integer- int()
     floating-point number- float()
     string - str()
    
#10. Why does this expression cause an error? How can you fix it?
'I have eaten ' + 99 + ' burritos.'
Ans. TypeError: can only concatenate str (not "int") to str
    Correct one: 'I have eaten ' + '99' + ' burritos.'
        output: 'I have eaten 99 burritos.'
