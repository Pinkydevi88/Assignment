# %% [markdown]
# 1. What does RGBA stand for?

# %% [markdown]
# Ans. Red-Green-Blue-Alpha

# %% [markdown]
# 2. From the Pillow module, how do you get the RGBA value of any images?

# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in c:\users\jijopinks\anaconda3\lib\site-packages (9.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image

# %%
img = Image.open('image.png')
rgba = img.convert("RGBA")
datas = rgba.getdata()

# %%
datas

# %% [markdown]
# 3. What is a box tuple, and how does it work?

# %% [markdown]
# Ans.
# Many of Pillow’s functions and methods take a box tuple argument. This means Pillow is expecting a tuple of four integer coordinates that represent a rectangular region in an image. The four integers are, in order, as follows:
#
# Left- The x-coordinate of the leftmost edge of the box.
#
# Top -The y-coordinate of the top edge of the box.
#
# Right -The x-coordinate of one pixel to the right of the rightmost edge of the box. This integer must be greater than the left integer.
#
# Bottom - The y-coordinate of one pixel lower than the bottom edge of the box. This integer must be greater than the top integer.
#
# For example, the box tuple (3, 1, 9, 6) represents all the pixels in the black box in the below picture:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 4. Use your image and load in notebook then, How can you find out the width and height of an Image object?

# %% [markdown]
# Ans.

# %%
from PIL import Image
Imm = Image.open('image.png')
Imm.size
width, height = img.size

# %%
width
# Out:
# 360

# %%
height
# Out:
# 360

# %% [markdown]
# 5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?

# %% [markdown]
# Ans.

# %%
from PIL import Image
Img = Image.open('download.png')
Img.size
# Out:
# (243, 207)

# %%
img_crop = img.crop((0,100,100,0))

# %%
img_crop.size
# Out:
# (100, 0)

# %% [markdown]
# 6. After making changes to an Image object, how could you save it as an image file?

# %% [markdown]
# Ans.

# %%
from PIL import Image
im = Image.open('astronaut_rect.jpg')
im_crop = im.crop((60, 20, 400, 200))
im_crop.save('astronaut_pillow_crop.jpg')

# %% [markdown]
# 7. What module contains Pillow’s shape-drawing code?

# %% [markdown]
# Ans. The ‘ImageDraw’ module provides simple 2D graphics support for Image Object.

# %% [markdown]
# 8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?

# %% [markdown]
# Ans. Drawing text does.
#
# The ImageDraw object also has a text() method for drawing text onto an image. The text() method takes four arguments: xy, text, fill, and font.
#
# The xy argument is a two-integer tuple specifying the upper-left corner of the text box.
# The text argument is the string of text you want to write.
# The optional fill argument is the color of the text.
# The optional font argument is an ImageFont object, used to set the typeface and size of the text. This is described in more detail in the next section.
